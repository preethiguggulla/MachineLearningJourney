# %%
#Print your name
name=input("Enetr your name ")
print("Hello "+name)
# Out:
# Enetr your name Preethi
# Hello Preethi

# %%
#Swap two numbers
a=int(input("Enter first number: "))
b=int(input("Enter second number: "))
temp=a
a=b
b=temp
print(f"Printing numbers after Swap a={a} b={b}")
# Out:
# Enter first numberr56
# Enter second number95
# Printing numbers after Swap a=95 b=56

# %%
#Area of circle
import math
radius=int(input("Enter radius of circle: "))
area=math.pi*(radius*radius)
print("Area of Circle: ",area)
# Out:
# Enter radius of circle: 5
# Area of Circle:  78.53981633974483

# %%
#Simple Calculater
num1=float(input("Enter first number: "))
num2=float(input("Enter second number: "))
print("Choose Operation")
print("1 Addition")
print("2 Subtraction")
print("3 Multiplication")
print("4 Division")
choice=int(input("Enter choice :"))
if choice==1:
  print("Addition: ",num1+num2)
elif choice==2:
  print("Subtraction: ",num1-num2)
elif choice==3:
  print("Multiplication: ",num1*num2)
elif choice==4:
  if(num2==0):
    print("Error, Cannot divide by zero")
  else:
    print("Division: ",num1/num2)
else:
  print("Invalid choice")
# Out:
# Enter first number: 50
# Enter second number: 0
# Choose Operation
# 1 Addition
# 2 Subtraction
# 3 Multiplication
# 4 Division
# Enter choice :4
# Error, Cannot divide by zero

# %%
#Reverse a string
String=input("Enter a string: ")
n=len(String)
revString=""
i=0
for i in range(n-1,-1,-1):
  revString=revString+String[i]
print("String After reversing: "+revString)
# Out:
# Enter a string: Preethi
# String After reversing: ihteerP

# %%
#Convert Celsius = Fahrenheit
print("1. Celsius to Fahrenheit")
print("2. Fahrenhit to Celsius")
choice =int(input("Enter your choice: "))
if choice==1:
  c=float(input("Enter Celsius: "))
  f=(c*(9/5))+32
  print("Fahrenheit:",f)
elif choice==2:
  f=float(input("Enter Fahrenheit: "))
  c=(f-32)*(5/9)
  print("Celsius:",c)
else:
  print("Invalid choice")
# Out:
# 1. Celsius to Fahrenheit
# 2. Fahrenhit to Celsius
# Enter your choice: 2
# Enter Fahrenheit: 32
# Celsius: 0.0

# %%
#Check Even or Odd
num=int(input("Enter Number: "))
if num%2==0 :
  print("Even number")
else :
  print("Odd number")
# Out:
# Enter Number: 11
# Odd number

# %%
#Sum of digits
num=int(input("Enter Number: "))
sum=0
for i in range(1,num+1):
  sum=sum+i
print("Sum of the number is: ",sum)
# Out:
# Enter Number: 10
# Sum of the number is:  55

# %%
#Largest of three numbers
a=int(input("Enter the first number: "))
b=int(input("Enter the second number: "))
c=int(input("Enter the third number: "))
if a>b and a>c :
  print("Largest number is: ",a)
elif b>a and b>c:
  print("Largest number is: ",b)
else:
  print("Largest number is: ",c)
# Out:
# Enter the first number: 15
# Enter the second number: 12
# Enter the third number: 60
# Largest number is:  60

# %%
#Count vowels
string=input("Enter a string: ")
c=0
n=len(string)
for i in range(0,n):
  if string[i] in "aeiouAEIOU":
    c=c+1

print("Vowels count is: ",c)
# Out:
# Enter a string: Siri
# Vowels count is:  2

# %%
#Factorial (loop)
num=int(input("Enter a number: "))
fact=1
for i in range(1,num+1):
  fact=fact*i
print("Factorial number is: ",fact)
# Out:
# Enter a number: 5
# Factorial number is:  120

# %%
#Fibonacci (loop)
num=int(input("Enter a number: "))
a=0
b=1
print("Fibonacci series: ")
print(0)
for i in range(0,num-1):
  c=a+b
  print(c)
  a=b
  b=c
# Out:
# Enter a number: 7
# Fibonacci series:
# 0
# 1
# 2
# 3
# 5
# 8
# 13

# %%
#Palindrome check
num=int(input("Enter the number: "))
p=bin(num)[2:]
count=0
if p==p[::-1]:
  print("Palindrome number")
else:
  print("Not a Palindrome number")
# Out:
# Enter the number: 9
# Palindrome number

# %%
#Remove spaces from string
String=input("Enter the string ")
s=String.replace(" ","")
print("String after removing Sapce:",s)
# Out:
# Enter the stringHello world
# String after removing Sapce Helloworld

# %%
#List → sum, max, min
nums=list(map(int,input("Enter numbers: ").split()))
sum=0
temp=0
c=nums[0]
for i in nums:
  sum=sum+i
  if(temp<i):
    temp=i

  if(c>i):
    c=i

print("Sum is:",sum)
print("Max: ",temp)
print("Min: ",c)
# Out:
# Enter numbers: 1 34 6 78 9 3
# Sum is: 131
# Max:  78
# Min:  1

# %%
#Dictionary operations
d = {"a": 1, "b": 2, "c": 3}
print(d["a"])
d["d"] = 4
d["a"] = 10
print(d)
# Out:
# 1
# {'a': 10, 'b': 2, 'c': 3, 'd': 4}

# %%
#Multiplication table
n=int(input("Enter a number: "))
for i in range(1,11):
  print(n,"X", i ,"=",n*i)
# Out:
# Enter a number: 10
# 10 X 1 = 10
# 10 X 2 = 20
# 10 X 3 = 30
# 10 X 4 = 40
# 10 X 5 = 50
# 10 X 6 = 60
# 10 X 7 = 70
# 10 X 8 = 80
# 10 X 9 = 90
# 10 X 10 = 100

# %%
#Prime number check
num = int(input("Enter a number: "))

if num < 2:
    print("Not a prime number")
else:
    for i in range(2, num):
        if num % i == 0:
            print("Not a prime number")
            break
    else:
        print("Prime number")
# Out:
# Enter a number: 10
# Not a prime number

# %%
#Count words in sentence
sentence = input("Enter a sentence: ")
words = sentence.split()
count = len(words)
print("Number of words:", count)
# Out:
# Enter a sentence: Preethi is a good girl
# Number of words: 5

# %%
#Percentage calculator
total_marks=float(input("Enter total marks: "))
marks_obtained=float(input("Enter obtained marks: "))
percentage=(marks_obtained/total_marks)*100
print("Percentage = ",percentage)
# Out:
# Enter total marks: 100
# Enter obtained marks: 10
# Percentage =  10.0

# %% [markdown]
# Day-1 Summary:
#
# Learned basic Python concepts like variables, strings, and numbers.
#
# Practiced taking user input and printing formatted output.
#
# Wrote several small programs to get comfortable with syntax.
#
# Set up my GitHub repository and uploaded my first notebook.
#
# Overall, built a solid foundation to continue with Day 2.
